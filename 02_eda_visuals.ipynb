# %% [markdown]
# # 02_eda_visuals.ipynb
#
# EDA: time-series, top aisles, AOV distributions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
DATA_DIR = Path('../data')
if (DATA_DIR/'orders.csv').exists():
    orders = pd.read_csv(DATA_DIR/'orders.csv', parse_dates=['order_time'])
    print('orders loaded', orders.shape)
else:
    print('orders.csv missing')
