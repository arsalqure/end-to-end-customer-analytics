# %% [markdown]
# # 03_rfm_cohort_analysis.ipynb
#
# Compute RFM scores and cohort retention tables.

# %%
import pandas as pd
from pathlib import Path
DATA_DIR = Path('../data')
print('Ready for RFM and cohort analysis')
