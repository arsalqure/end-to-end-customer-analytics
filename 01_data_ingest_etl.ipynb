# %% [markdown]
# # 01_data_ingest_etl.ipynb
#
# This notebook ingests raw CSVs (from Kaggle), performs basic cleaning, and demonstrates loading into SQLite.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
print('Notebook ready')

# %%
DATA_DIR = Path('../data')
print('Data dir:', DATA_DIR)
# Load samples if present
for f in ['orders.csv','products.csv','order_products__prior.csv']:
    p = DATA_DIR/f
    if p.exists():
        print(p.name, 'found — shape:', pd.read_csv(p, nrows=5).shape)
    else:
        print(p.name, 'not found — run scripts/etl_run.py to download')
